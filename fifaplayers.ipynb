# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

#Convert CSV File to DataFrame
dataframe = pd.read_csv("fifaPlayers.csv")

#Set the query to display all the columns
pd.options.display.max_columns = len(dataframe.columns)

#Print 5 records from the dataframe. head() prints 5 by default
dataframe.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  overall  potential  \
# ...

# %%
#Display all the coulmn names
dataframe.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club',
#        ...
#        'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object', length=104)

# %%
#Covert the columns name to list to be able to view each coulmn name
dataframe.columns.tolist()
# Out:
# ['sofifa_id',
#  'player_url',
#  'short_name',
#  'long_name',
#  'age',
#  'dob',
#  'height_cm',
#  'weight_kg',
#  'nationality',
#  'club',
#  'overall',
#  'potential',
#  'value_eur',
#  'wage_eur',
#  'player_positions',
#  'preferred_foot',
#  'international_reputation',
#  'weak_foot',
#  'skill_moves',
#  'work_rate',
#  'body_type',
#  'real_face',
#  'release_clause_eur',
#  'player_tags',
#  'team_position',
#  'team_jersey_number',
#  'loaned_from',
#  'joined',
#  'contract_valid_until',
#  'nation_position',
#  'nation_jersey_number',
#  'pace',
#  'shooting',
#  'passing',
#  'dribbling',
#  'defending',
#  'physic',
#  'gk_diving',
#  'gk_handling',
#  'gk_kicking',
#  'gk_reflexes',
#  'gk_speed',
#  'gk_positioning',
#  'player_traits',
#  'attacking_crossing',
#  'attacking_finishing',
#  'attacking_heading_accuracy',
#  'attacking_short_passing',
#  'attacking_volleys',
#  'skill_dribbling',
#  'skill_curve',
#  'skill_fk_accuracy',
#  'skill_long_passing',
# ...

# %%
#Number of rows and column (rows, column)
dataframe.shape
# Out:
# (18278, 104)

# %%
#Count the number of player in each country
dataframe.groupby('nationality').size()
# Out:
# nationality
# Afghanistan            2
# Albania               43
# Algeria               50
# Angola                16
# Antigua & Barbuda      7
#                     ...
# Venezuela             66
# Vietnam                1
# Wales                117
# Zambia                10
# Zimbabwe              12
# Length: 162, dtype: int64

# %%
#Top 10 contries for the highest number of player
dataframe.groupby('nationality').size().nlargest(10)
# Out:
# nationality
# England        1667
# Germany        1216
# Spain          1035
# France          984
# Argentina       886
# Brazil          824
# Italy           732
# Colombia        591
# Japan           453
# Netherlands     416
# dtype: int64

# %%
#Top 5 Countries for the highest number of player
topFiveCountry =  dataframe.groupby('nationality').size().nlargest(5)

# Horizontal Bar Plot
plt.style.use('ggplot')
ax = topFiveCountry.plot(kind='barh', color='#61D199', title='Top 5 Countries with Highest Number Of Players')
ax.set_xlabel('Players Count')
ax.set_ylabel('Nationality')
# Out:
# Text(0, 0.5, 'Nationality')

# %%
#Top 5 players with highest stat and their respective wage 
topFiveWages = dataframe.sort_values('overall', ascending=False).head()
topFiveWages[['short_name', 'wage_eur']]
# Out:
#           short_name  wage_eur
# 0           L. Messi    565000
# 1  Cristiano Ronaldo    405000
# 2          Neymar Jr    290000
# 3           J. Oblak    125000
# 4          E. Hazard    470000

# %%
#Top 5 players with highest wage
topFiveHighestPaid = dataframe.sort_values('wage_eur', ascending=False).head()
topFiveHighestPaid[['short_name', 'wage_eur']]
# Out:
#            short_name  wage_eur
# 0            L. Messi    565000
# 4           E. Hazard    470000
# 1   Cristiano Ronaldo    405000
# 5        K. De Bruyne    370000
# 22       A. Griezmann    370000

# %%
#Vertical Bar Plot for player with highest salary 
plt.style.use('ggplot')
ax = topFiveHighestPaid.plot(kind='bar', x='short_name', y='wage_eur', color='#61D199', title='Top 5 Players with Highest Salary')
ax.set_xlabel('Player')
ax.set_ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %%
#Group players by their nationality
nationality = dataframe.groupby('nationality')

#Top 10 players from Germany based on their overall score
nationality.get_group('Germany').sort_values('overall', ascending=False).head(10)
# Out:
#      sofifa_id                                         player_url  \
# 6       192448  https://sofifa.com/player/192448/marc-andre-te...
# 36      182521  https://sofifa.com/player/182521/toni-kroos/20...
# 37      188350  https://sofifa.com/player/188350/marco-reus/20...
# 31      167495  https://sofifa.com/player/167495/manuel-neuer/...
# 49      178603  https://sofifa.com/player/178603/mats-hummels/...
# 55      222492  https://sofifa.com/player/222492/leroy-sane/20...
# 61      212622  https://sofifa.com/player/212622/joshua-kimmic...
# 70      189596  https://sofifa.com/player/189596/thomas-muller...
# 77      212190  https://sofifa.com/player/212190/niklas-sule/2...
# 122     192563  https://sofifa.com/player/192563/bernd-leno/20...
#
#         short_name              long_name  age         dob  height_cm  \
# 6    M. ter Stegen  Marc-André ter Stegen   27  1992-04-30        187
# 36        T. Kroos             Toni Kroos   29  1990-01-04        183
# ...

# %%
#Top 5 German player based on their height, weight and wage respectively
nationality.get_group('Germany').sort_values(['height_cm','weight_kg', 'wage_eur'], ascending=False).head()
# Out:
#        sofifa_id                                         player_url  \
# 8016      236831  https://sofifa.com/player/236831/aaron-seydel/...
# 1389      199833  https://sofifa.com/player/199833/lars-unnersta...
# 1217      200212  https://sofifa.com/player/200212/michael-esser...
# 13576     239746  https://sofifa.com/player/239746/lukas-watkowi...
# 518       179783  https://sofifa.com/player/179783/ralf-fahrmann...
#
#           short_name        long_name  age         dob  height_cm  weight_kg  \
# 8016       A. Seydel     Aaron Seydel   23  1996-02-07        199         90
# 1389   L. Unnerstall  Lars Unnerstall   28  1990-07-20        198        103
# 1217        M. Esser    Michael Esser   31  1987-11-22        198         97
# 13576   L. Watkowiak  Lukas Watkowiak   23  1996-03-06        197        103
# 518      R. Fährmann    Ralf Fährmann   30  1988-09-27        197         98
#
#       nationality                club  overall  potential  value_eur  \
# ...

# %%
#Top 5 German players with higest wage
topFiveHighestPaidGerman = nationality.get_group('Germany').sort_values('wage_eur', ascending=False).head()
topFiveHighestPaidGerman[['short_name', 'wage_eur']]
# Out:
#         short_name  wage_eur
# 36        T. Kroos    330000
# 6    M. ter Stegen    250000
# 55         L. Sané    195000
# 146    I. Gündoğan    180000
# 70       T. Müller    170000

# %%
#Top 5 fifa players with highest shooting stats
topFiveInShooting = dataframe.sort_values('shooting', ascending=False).head()
topFiveInShooting[['short_name', 'shooting']]
# Out:
#             short_name  shooting
# 1    Cristiano Ronaldo      93.0
# 0             L. Messi      92.0
# 12             H. Kane      91.0
# 17           S. Agüero      90.0
# 205    F. Quagliarella      89.0

# %%
#Top 5 players records (short name, defending, nationality, and club) that have awesome defending skills
topFiveInDefending = dataframe.sort_values('defending', ascending=False).head()
topFiveInDefending[['short_name', 'defending', 'nationality', 'club']]
# Out:
#       short_name  defending  nationality               club
# 16  G. Chiellini       90.0        Italy           Juventus
# 7    V. van Dijk       90.0  Netherlands          Liverpool
# 11  K. Koulibaly       89.0      Senegal             Napoli
# 35      D. Godín       89.0      Uruguay              Inter
# 49    M. Hummels       89.0      Germany  Borussia Dortmund

# %%
#Group the dataframe based on the club
club = dataframe.groupby('club')

#Wages records of top 5 players of 'Real Madrid' team
RealMadrid = club.get_group('Real Madrid')
topWage = RealMadrid.sort_values('wage_eur', ascending=False)
topWage[['short_name', 'wage_eur']].head()
# Out:
#       short_name  wage_eur
# 4      E. Hazard    470000
# 8      L. Modrić    340000
# 36      T. Kroos    330000
# 18  Sergio Ramos    300000
# 46    K. Benzema    285000

# %%
#Shooting records of top 5 players of 'Real Madrid' team.
topShooting = RealMadrid.sort_values('shooting', ascending=False)
topShooting[['short_name', 'shooting']].head()
# Out:
#        short_name  shooting
# 100       G. Bale      87.0
# 106  J. Rodríguez      86.0
# 4       E. Hazard      83.0
# 46     K. Benzema      82.0
# 161      L. Jović      82.0

# %%
#Defending records of top 5 players of 'Real Madrid' team
topDefending = RealMadrid.sort_values('defending', ascending=False)
topDefending[['short_name', 'defending']].head()
# Out:
#        short_name  defending
# 18   Sergio Ramos       87.0
# 42       Casemiro       85.0
# 76      R. Varane       85.0
# 94       Carvajal       82.0
# 332  Éder Militão       81.0

# %%
#Nationality records of top 5 players of 'Real Madrid' team
playerNationality = RealMadrid.sort_values('overall', ascending=False)
playerNationality[['short_name', 'overall', 'nationality']].head()
# Out:
#       short_name  overall nationality
# 4      E. Hazard       91     Belgium
# 8      L. Modrić       90     Croatia
# 18  Sergio Ramos       89       Spain
# 28   T. Courtois       88     Belgium
# 36      T. Kroos       88     Germany

# %%
#Get the best club based on mean of an overall of score
club.agg({'overall': 'mean',}).sort_values('overall', ascending=False).head(10)
# Out:
#                        overall
# club
# FC Bayern München    81.304348
# Real Madrid          80.121212
# Juventus             80.060606
# Uruguay              78.608696
# FC Barcelona         78.363636
# Mexico               78.000000
# Netherlands          78.000000
# Colombia             78.000000
# Bayer 04 Leverkusen  77.280000
# Chelsea              77.060606
